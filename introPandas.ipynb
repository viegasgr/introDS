# %% [markdown]
# <a href="https://colab.research.google.com/github/viegasgr/introDS/blob/main/introPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Pandas: conhecendo a biblioteca**

# %% [markdown]
# ###AULA 1: Conhecendo a base de dados

# %%
import pandas as pd

url_bd = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
aluguel = pd.read_csv(url_bd, sep=';') #nosso banco de dados tem por separador o ;, e, dessa forma, avisamos ao pandas isso.

# %%
aluguel.head() #mostra os 5 primeiros dados
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
aluguel.tail() #mostra os 5 ultimos dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %% [markdown]
# *Conhecendo a base de dados*

# %%
aluguel.shape #verifica a qtd de linhas e colunas
# Out:
# (32960, 9)

# %%
aluguel.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
aluguel.info() #traz o tipo de cada coluna junto com a qtd de dados n nulos

'''
Tipos de dados:
> object - strings, texto
> int64 - inteiros
> float64 - decimais
'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB
# '\nTipos de dados:\n> object - strings, texto\n> int64 - inteiros\n> float64 - decimais\n'

# %% [markdown]
# ####**Desafio**

# %%
aluguel.head(7)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN
# 5  1200.0         NaN     NaN
# 6  1300.0       301.0    17.0

# %%
aluguel.tail(5)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
aluguel.shape
# Out:
# (32960, 9)

# %%
aluguel.dtypes #tipo de cada coluna
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
aluguel.describe()
#nos informa, para cada coluna: qtd de dados; média aritmética; desvio padrão; valor mínimo; valor q divide os dados em 25%;
#valor que divide os dados em 50%; valor que divide os dados em 75%; valor máximo
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %% [markdown]
# ###AULA 2: Análise exploratória de dados

# %% [markdown]
# ####Card 1: Valores médios de imóvel e percentual de cada tipo de imóvel presente na base de dados

# %% [markdown]
# *Em primeiro lugar, tirar a média de preço dos imóveis*

# %%
aluguel.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
aluguel['Valor'].mean() #média de tudo
# Out:
# 12952.659715265761

# %%
aluguel.groupby('Tipo').mean(numeric_only=True) #esse parâmetro no método mean vai fazer com que só seja tirada a média das colunas numéricas
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
df_preco_tipo = aluguel.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
#os colchetes duplos fazem com q seja gerado um DATAFRAME ao inves de uma série
#o sort_values() vai trazer do menor valor para o maior

# %%
df_preco_tipo.plot(kind='barh', figsize=(14,10), color='purple') #achamos o valor médio por tipo de imóvel, hurray!
# Out:
# <Axes: ylabel='Tipo'>

# %%
#vamos agora explorar por tipo, separando os comerciais dos residenciais
aluguel['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
aluguel.query('@imoveis_comerciais in Tipo')
#estamos selecionando os valores da coluna Tipo que estão na lista "imoveis_comerciais". o @ é para passar uma variável no query.
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df_residenciais = aluguel.query('@imoveis_comerciais not in Tipo') #o contrário da seleção anterior
df_residenciais.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df_residenciais['Tipo'].unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo_res = df_residenciais.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_preco_tipo_res.plot(kind='barh', figsize=(14,10), color='purple') #plota o gráfico das médias de valor dos imóveis residenciais
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# *Agora veremos o percentual de cada imóvel residencial:*

# %%
df_residenciais['Tipo'].value_counts(normalize=True) #esse parâmetro faz os números serem mostrados em percentual
df_perc_tipo_res = df_residenciais['Tipo'].value_counts(normalize=True).to_frame().sort_values('Tipo') #transforma em df e do menor p maior
df_perc_tipo_res.rename(columns={'Tipo': 'Percentuais'}, inplace=True) #muda o nome da coluna para o nome desejado
df_perc_tipo_res
# Out:
#                     Percentuais
# Studio                 0.000173
# Loft                   0.002207
# Casa de Vila           0.010774
# Flat                   0.020596
# Quitinete              0.036173
# Casa                   0.041842
# Casa de Condomínio     0.043096
# Apartamento            0.845139

# %%
df_perc_tipo_res.plot(kind='bar', figsize=(14, 10), color ='green', edgecolor='black', xlabel = 'Tipos', ylabel = 'Percentual'); #visu c grafico

# %% [markdown]
# A partir da análise do gráfico anterior, é possível perceber que os apts representam mais de 80% dos imóveis residenciais. Sabendo-se que os preços entre casas e apts podem variar muito por suas características distintas, faz sentido querer manter na base de dados apenas os apts.

# %%
df_apt = df_residenciais.query('Tipo == "Apartamento"')
df_apt.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ####**Desafio**

# %%
df_apt['Quartos'].mean().round()
# Out:
# 2.0

# %%
df_apt['Bairro'].value_counts() #o length nos informa que existem 149 bairros únicos
# Out:
# Barra da Tijuca             3341
# Copacabana                  2465
# Ipanema                     1768
# Recreio dos Bandeirantes    1490
# Leblon                      1241
#                             ...
# Caju                           1
# Parque Anchieta                1
# Cidade Jardim                  1
# Coelho Neto                    1
# Grumari                        1
# Name: Bairro, Length: 149, dtype: int64

# %%
df_apt['Bairro'].nunique() #alternativa que informa exatamente a qtd de valores únicos
# Out:
# 149

# %%
df_valor_bairros = df_apt.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False) #mostra de maneira decrescente a média de aluguéis.
os_5_mais = df_valor_bairros.head() #pegando os 5 mais caros
os_5_mais
# Out:
#                       Valor
# Bairro
# Joá            15500.000000
# Arpoador       12429.769231
# Cidade Jardim  12000.000000
# Ipanema         9487.205317
# Botafogo        9369.207116

# %%
os_5_mais.plot(kind='bar', figsize=(7, 5), color ='green', edgecolor='black', xlabel = 'Bairro', ylabel = 'Valor do Aluguel')
# Out:
# <Axes: xlabel='Bairro', ylabel='Valor do Aluguel'>

# %%
os_5_menos = df_valor_bairros.tail() #pegando os 5 mais baratos
os_5_menos
# Out:
#                         Valor
# Bairro
# Inhoaíba                650.0
# Cosmos                  610.0
# Santa Cruz              590.0
# Paciência               510.0
# Ricardo de Albuquerque  340.0

# %%
os_5_menos.plot(kind='bar', figsize=(7, 5), color ='red', edgecolor='black', xlabel = 'Bairro', ylabel = 'Valor do Aluguel')
# Out:
# <Axes: xlabel='Bairro', ylabel='Valor do Aluguel'>

# %% [markdown]
# ###AULA 3: Tratando e Filtrando Dados

# %%
df_apt.isnull() #informa quais células estão vazias no df
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %%
df_apt.isnull().sum() #informa QUANTOS dados são nulos por coluna. true=1
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
df_apt = df_apt.fillna(0) #vai substituir todas as células nulas por '0'. funciona bem pq todas as colunas que achou-se nesse df são numéricas.
df_apt
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   0.0
# ...

# %%
'''
Outras maneiras de tratar dados nulos incluem:
> dropna() : apaga a linha que tiver o dado nulo
> fillna(method = 'ffill') : preenche com o valor anterior
> fillna(method = 'bfill') : preenche com o valor posterior
> interpolate() : preencher dados nulos com valores calculados a partir dos vizinhos
'''

# %%
registros_a_remover = df_apt.query('Valor==0 | Condominio==0').index #pega o index das linhas cujo valor/condominio = 0

# %%
df_apt.drop(registros_a_remover, axis=0, inplace = True)
#o método axis=0 indica que vai limpar as linhas com os index informados. se fosse axis=1, removeria as colunas
#inplace = True muda direto no df_apt, sem precisar atribuir a df_apt

# %%
df_apt.drop('Tipo', axis=1, inplace = True) #vai remover a coluna 'Tipo', que não faz sentido uma vez que esse df é só de apts

# %%
#Para além do .query(), existem formas mais manuais de filtrar dados
selecao1 = df_apt['Quartos'] == 1
df_apt[selecao1] #retorna apenas as linhas em que a selecao1 é True
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
selecao2 = df_apt['Valor'] < 1200.0
df_apt[selecao2] #retorna apenas as linhas em que a selecao2 é True
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
selecao_final = (selecao1) & (selecao2)
df_apt_filtro1 = df_apt[selecao_final] #filtro1: Apts com 1 qt e aluguel menor q 1200

# %%
selecao3 = (df_apt['Quartos'] >= 2) & (df_apt['Valor'] < 3000) & (df_apt['Area'] > 70)
df_apt_filtro2 = df_apt[selecao3] #filtro2: Apts com no mín 2 qts, aluguel menos q 3000 e area maior q 70m²

# %%
df_apt.to_csv('dados_apts.csv') #salva o dataframe em um csv com o nome especificado

# %%
pd.read_csv('dados_apts.csv') #essa linha 'unnamed:0' se refere aos antigos indices do df.
# Out:
#        Unnamed: 0                Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0               3                Centro        1      0       0    15   800.0
# 1               4          Higienópolis        1      0       0    48   800.0
# 2               6              Cachambi        2      0       0    50  1300.0
# 3              11                Grajaú        2      1       0    70  1500.0
# 4              12   Lins de Vasconcelos        3      1       1    90  1500.0
# ...           ...                   ...      ...    ...     ...   ...     ...
# 18775       32951        Vila Valqueire        2      0       0    52  1000.0
# 18776       32953                 Méier        2      0       0    70   900.0
# 18777       32956           Jacarepaguá        3      1       2    78  1800.0
# 18778       32957  São Francisco Xavier        2      1       0    48  1400.0
# 18779       32958                Leblon        2      0       0    70  3000.0
#
#        Condominio  IPTU
# ...

# %%
df_apt.to_csv('dados_apts.csv', index=False) #tira o index
pd.read_csv('dados_apts.csv')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %%
df_apt.to_csv('dados_apts.csv', index=False, sep=';') #retorna ao padrão de salvar dividindo por ;, como estava anteriormente

# %% [markdown]
# ####**Desafios**

# %% [markdown]
# Desafio 1: Salvar os filtros em arquivos .csv

# %%
df_apt_filtro1.to_csv('filtro1.csv', index=False, sep=';')
df_apt_filtro2.to_csv('filtro2.csv', index=False, sep=';')

# %% [markdown]
# Desafio 2: Usando outro bd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df_alunos = pd.read_csv(url)

# %%
df_alunos.isnull().sum() #verificando quais colunas tem dados nulos.
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
#apenas a coluna 'notas' tem dados nulos, ou seja, provavelmente os alunos não tinham nota. a nota de quem não tem nota é 0:

df_alunos = df_alunos.fillna(0)
#mas vamos conferir se eles estão reprovados
df_alunos.query('Notas==0') #estão, logo está ok fazer o q fiz.
# Out:
#       Nome  Idade  Notas  Aprovado
# 1      Ana     18    0.0     False
# 5    Bruna     23    0.0     False
# 9    Vitor     28    0.0     False
# 10  Daniel     21    0.0     False
# 14   Paulo     37    0.0     False
# 16   Lucas     33    0.0     False

# %%
remover = df_alunos.query('Nome=="Alice" | Nome=="Carlos"').index
df_alunos.drop(remover, axis=0, inplace=True) #exclui os alunos Alice e Carlos, que não fazem mais parte da turma.

# %%
aprovados = df_alunos['Aprovado'] == True #filtro que seleciona apenas os aprovados
alunos_aprovados = df_alunos[aprovados].drop('Aprovado', axis=1) #não precisamos mais da coluna "aprovado"
alunos_aprovados
# Out:
#          Nome  Idade  Notas
# 0         Ary     20    7.5
# 4        Beto     21   10.0
# 6        Dara     21    7.0
# 12  Sthefanie     26    9.5
# 13      Mirla     25    9.0
# 15     Mylena     29    7.0
# 17      Nadia     34    8.0

# %%
alunos_aprovados.to_csv('alunos_aprovados.csv', index=False)

# %% [markdown]
# Extra: replace 7.0 with 8.0

# %%
df_aprov = pd.read_csv('alunos_aprovados.csv')
df_aprov
# Out:
#         Nome  Idade  Notas
# 0        Ary     20    7.5
# 1       Beto     21   10.0
# 2       Dara     21    7.0
# 3  Sthefanie     26    9.5
# 4      Mirla     25    9.0
# 5     Mylena     29    7.0
# 6      Nadia     34    8.0

# %%
df_aprov_corr = df_aprov.replace(7.0, 8.0)
df_aprov_corr.to_csv('alunos_aprovados_corr.csv', index=False)
pd.read_csv('alunos_aprovados_corr.csv')
# Out:
#         Nome  Idade  Notas
# 0        Ary     20    7.5
# 1       Beto     21   10.0
# 2       Dara     21    8.0
# 3  Sthefanie     26    9.5
# 4      Mirla     25    9.0
# 5     Mylena     29    8.0
# 6      Nadia     34    8.0

# %% [markdown]
# ###AULA 4: Manipulando os dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %% [markdown]
# Criando colunas numéricas:

# %%
dados['valor_por_mes'] = dados['Valor'] + dados['Condominio']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dados['valor_por_ano'] = (dados['valor_por_mes'] * 12) + dados['IPTU']
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  valor_por_mes  valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# Criando colunas categóricas:

# %%
#coluna que descreve o apt
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com ' + \
                                        dados['Quartos'].astype(str) + ' quarto(s) ' + \
                                        ' e ' + dados['Vagas'].astype(str) + ' vaga(s) de garagem.'
#a barra invertida serve para continuar um comando na linha seguinte
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  valor_por_mes  valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                     Descrição  \
# 0                     Quitinete em Copacabana
# 1                     Casa em Jardim Botânico
# ...

# %%
#coluna que diz se tem suite ou nao
dados['Possui_suite'] = dados['Suites'].apply(lambda x: 'Sim' if x>0 else 'Não')
#.apply serve p aplicar uma função em um conjunto de dados.
#lambda são funções anônimas do python, escritas em uma linha apenas e q n vão ser reutilizadas no código. sintaxe básica: lambda {argumentos}: {expressão}

dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  valor_por_mes  valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                     Descrição  \
# 0                     Quitinete em Copacabana
# 1                     Casa em Jardim Botânico
# ...

# %%
dados.to_csv('dados_completos_dev.csv', index=False, sep=';')

# %% [markdown]
# ####**Desafio**

# %%
#vamos reaproveitar o csv tratado de lá de cima.
df_alunos.head() #não tem alice nem carlos, alunos com NaN tem zero na nota
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    0.0     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %%
df_alunos['Pontos_extras'] = df_alunos['Notas'] * 0.4 #criando uma coluna que contabiliza os pontos extras: 40% da nota inicial
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras
# 0    Ary     20    7.5      True            3.0
# 1    Ana     18    0.0     False            0.0
# 2  Cátia     27    2.5     False            1.0
# 3  Denis     18    5.0     False            2.0
# 4   Beto     21   10.0      True            4.0

# %%
df_alunos['Notas_finais'] = df_alunos['Notas'] + df_alunos['Pontos_extras'] #somando os pontos extras
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0    Ary     20    7.5      True            3.0          10.5
# 1    Ana     18    0.0     False            0.0           0.0
# 2  Cátia     27    2.5     False            1.0           3.5
# 3  Denis     18    5.0     False            2.0           7.0
# 4   Beto     21   10.0      True            4.0          14.0

# %%
df_alunos['Aprovado_final'] = df_alunos['Notas_finais'].apply(lambda x: True if x>6.0 else False) #atualizando a lista de aprovados
df_alunos.head()
# Out:
#     Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovado_final
# 0    Ary     20    7.5      True            3.0          10.5            True
# 1    Ana     18    0.0     False            0.0           0.0           False
# 2  Cátia     27    2.5     False            1.0           3.5           False
# 3  Denis     18    5.0     False            2.0           7.0            True
# 4   Beto     21   10.0      True            4.0          14.0            True

# %%
df_alunos.query('Aprovado == False & Aprovado_final == True') #verificando quem foi aprovado agora.
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovado_final
# 3   Denis     18    5.0     False            2.0           7.0            True
# 11   Igor     24    4.5     False            1.8           6.3            True

# %% [markdown]
# ###EXTRA: Tratando Outliers

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://caelum-online-public.s3.amazonaws.com/856-introducao-python-pandas/09/aluguel_amostra.csv'

dados = pd.read_csv(url, sep=';')
dados.head()
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 3  Apartamento               São Conrado        3      3       3   270
# 4  Apartamento                    Tijuca        2      1       0    65
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   3200.0      1319.0     0.0     10.00   Apartamento
# 1    800.0       725.0    47.0     13.56   Apartamento
# 2   7500.0      1000.0   381.0     51.02   Apartamento
# 3  14999.0      2800.0  1200.0     55.55   Apartamento
# 4   1200.0       640.0    97.0     18.46   Apartamento

# %%
dados.boxplot(['Valor']) #visualização prejudicada pelos Outliers
# Out:
# <Axes: >

# %%
dados[dados['Valor'] >= 500000] #pegando apenas os dados discrepantes
# Out:
#                     Tipo                    Bairro  Quartos  Vagas  Suites  \
# 535          Apartamento  Recreio dos Bandeirantes        3      2       1
# 726   Casa de Condomínio   Freguesia (Jacarepaguá)        4      2       3
# 7493         Apartamento                  Botafogo        4      1       1
#
#       Area      Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 535    167  1250000.0      1186.0  320.0   7485.03   Apartamento
# 726    163   800000.0       900.0    0.0   4907.98          Casa
# 7493   300  4500000.0      1100.0    0.0  15000.00   Apartamento

# %%
valor = dados['Valor'] #facilitar o trabalho
Q1 = valor.quantile(.25) #primeiro quartil
Q3 = valor.quantile(.75) #último quartil
IIQ = Q3 - Q1 #intervalo interquartílico
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >=limite_inferior) & (valor <= limite_superior)
dados_new = dados[selecao] #pegando os dados apenas no intervalo IIQ
dados_new.head()
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 4  Apartamento                    Tijuca        2      1       0    65
# 5  Apartamento                  Cachambi        2      1       1    75
#
#     Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 0  3200.0      1319.0    0.0     10.00   Apartamento
# 1   800.0       725.0   47.0     13.56   Apartamento
# 2  7500.0      1000.0  381.0     51.02   Apartamento
# 4  1200.0       640.0   97.0     18.46   Apartamento
# 5  1400.0       715.0    0.0     18.67   Apartamento

# %%
dados_new.boxplot(['Valor']) #boxplot muito mais visível, com dados mais consistentes
# Out:
# <Axes: >

# %%
dados.hist(['Valor']) #a presença de outliers mt absurdos faz com que o histograma fique ruim de visualizar
dados_new.hist(['Valor']) #melhor visualizavel
# Out:
# array([[<Axes: title={'center': 'Valor'}>]], dtype=object)

# %% [markdown]
# Agora com o valor por m2

# %%
dados.boxplot(['Valor m2'])
# Out:
# <Axes: >

# %%
dados[dados['Valor m2'] >= 2000] #pegando apenas os dados discrepantes visualmente
# Out:
#                     Tipo                    Bairro  Quartos  Vagas  Suites  \
# 535          Apartamento  Recreio dos Bandeirantes        3      2       1
# 726   Casa de Condomínio   Freguesia (Jacarepaguá)        4      2       3
# 7493         Apartamento                  Botafogo        4      1       1
#
#       Area      Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 535    167  1250000.0      1186.0  320.0   7485.03   Apartamento
# 726    163   800000.0       900.0    0.0   4907.98          Casa
# 7493   300  4500000.0      1100.0    0.0  15000.00   Apartamento

# %%
valorm2 = dados['Valor m2'] #facilitar o trabalho
Q1 = valorm2.quantile(.25) #primeiro quartil
Q3 = valorm2.quantile(.75) #último quartil
IIQ = Q3 - Q1 #intervalo interquartílico
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ
print(Q1, Q3, IIQ, limite_inferior, limite_superior)
# Out:
# 21.25 42.31 21.060000000000002 -10.340000000000003 73.9

# %%
selecao = (valorm2 >=limite_inferior) & (valorm2 <= limite_superior)
dados_new_m2 = dados[selecao] #pegando os dados apenas no intervalo IIQ
dados_new_m2.head()
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 3  Apartamento               São Conrado        3      3       3   270
# 4  Apartamento                    Tijuca        2      1       0    65
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   3200.0      1319.0     0.0     10.00   Apartamento
# 1    800.0       725.0    47.0     13.56   Apartamento
# 2   7500.0      1000.0   381.0     51.02   Apartamento
# 3  14999.0      2800.0  1200.0     55.55   Apartamento
# 4   1200.0       640.0    97.0     18.46   Apartamento

# %%
dados_new_m2.boxplot(['Valor m2']) #boxplot muito mais visível, com dados mais consistentes
# Out:
# <Axes: >

# %%
dados.hist(['Valor m2']) #a presença de outliers mt absurdos faz com que o histograma fique ruim de visualizar
dados_new_m2.hist(['Valor m2']) #melhor visualizavel
# Out:
# array([[<Axes: title={'center': 'Valor m2'}>]], dtype=object)

# %% [markdown]
# Agora analisando o boxplot por tipo:

# %%
dados.boxplot(['Valor'], by = ['Tipo'])
# Out:
# <Axes: title={'center': 'Valor'}, xlabel='[Tipo]'>

# %%
grupo_tipo = dados.groupby('Tipo')['Valor'] #agrupando os dados por tipo

Q1 =  grupo_tipo.quantile(.25, numeric_only=True)
Q3 =  grupo_tipo.quantile(.75, numeric_only=True)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
dados_new = pd.DataFrame()

for tipo in grupo_tipo.groups.keys(): #seleciona os valores apenas dentro do IIQ
    eh_tipo = dados['Tipo'] == tipo
    eh_dentro_limite = (dados['Valor'] >= limite_inferior[tipo]) & (dados['Valor'] <= limite_superior[tipo])
    selecao = eh_tipo & eh_dentro_limite
    dados_sel = dados[selecao]
    dados_new = pd.concat([dados_new, dados_sel])

# %%
dados_new.boxplot(['Valor'], by = ['Tipo']) #mais organizado
# Out:
# <Axes: title={'center': 'Valor'}, xlabel='[Tipo]'>

# %%
dados_new.to_csv('aluguel_residencial_sem_outliers.csv', sep = ';', index = False) #salva em um csv

# %% [markdown]
# Extra: Gráficos

# %%
area = plt.figure()
g1 = area.add_subplot(1, 2, 1)
g2 = area.add_subplot(1, 2, 2)
grupo1 = dados.groupby('Tipo Agregado')['Valor']
label = grupo1.count().index
valores = grupo1.count().values
g1.pie(valores, labels = label, autopct='%1.1f%%')
g1.set_title('Total de Imóveis por Tipo Agregado')
grupo2 = dados.groupby('Tipo')['Valor']
label = grupo2.count().index
valores = grupo2.count().values
g2.pie(valores, labels = label, autopct='%1.1f%%', explode = (.1, .1, .1, .1, .1))
g2.set_title('Total de Imóveis por Tipo')
# Out:
# Text(0.5, 1.0, 'Total de Imóveis por Tipo')
